# %% [markdown]
# Compare results of Linear SVM classifiers trained using features extracted pre-trained Convolutional Neural Networks.
#
# The pre-trained models used were:
#
# - BVLC AlexNet Model (http://dl.caffe.berkeleyvision.org/bvlc_alexnet.caffemodel)
# - VGGNet (https://gist.github.com/ksimonyan/fd8800eeb36e276cd6f9#file-readme-md)
#
# For each CNN, three sets of features were used based upon the outputs of Fully Connected layers 6, 7 and 8.
#
# All of the processing work was performed on an AWS g2.2xlarge GPU instance.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, sys
import pickle
import sklearn.metrics as metrics
sys.path.append('../')
import helpers.histogram_classifier as hc

# set display defaults
plt.rcParams['figure.figsize'] = (10, 10)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
from IPython.core.display import HTML
css = open('styles/table-style.css').read() #+ open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
#     font-size: 12px;
# }
# table.dataframe tr {
#     border: none;
#     line-height: 14px;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.7em;
#     padding-right: 0.7em;
# }
# table.dataframe th {
#     background-color: #1c9099;
#     text-align: center;
#     font-weight: normal;
#     color: white;
# }
# table.dataframe td {
#     border: 1px solid #ccf;
#     background-color: #f4f4ff;
#     text-align: center;
# }
# </style>

# %%
classes = pd.read_csv('../data/food-101/meta/top_classes.csv', index_col=0)
class_list = list(classes['class'].unique())

# %% [markdown]
# ##### Alexnet Layer 8 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_8_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_8_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.645  0.642      0.642   0.645

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.57    0.49      0.53    212.0
# lasagna              0.59    0.62      0.61    184.0
# french_toast         0.62    0.57      0.60    202.0
# guacamole            0.81    0.89      0.85    195.0
# apple_pie            0.58    0.51      0.54    207.0
# cheesecake           0.60    0.63      0.62    196.0
# hamburger            0.70    0.76      0.73    203.0
# fried_rice           0.76    0.77      0.76    202.0
# carrot_cake          0.63    0.58      0.60    212.0
# chocolate_cake       0.67    0.70      0.69    191.0
# steak                0.47    0.48      0.47    193.0
# pizza                0.70    0.75      0.72    203.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop             103        7             8          4         10
# lasagna                 6      114             2          1          9
# french_toast            3       13           116          3         14
# guacamole               0        2             1        174          0
# apple_pie               6        8            20          5        106
# cheesecake              3        6             4          1          8
# hamburger               5        3             7          5          9
# fried_rice              4        7             3          7          5
# carrot_cake             8        6             8          2         11
# chocolate_cake          1        0             3          5          3
# steak                  40        9            12          7          2
# pizza                   1       17             2          2          7
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                1         10           8            3
# lasagna                  2          5          11            8
# french_toast            14         11           3            2
# guacamole                0          8           4            1
# apple_pie               13         10           5           19
# cheesecake             124          9           4           13
# hamburger                3        154           1            0
# fried_rice               1          2         156            3
# carrot_cake             24          1           4          123
# chocolate_cake          16          3           1           17
# steak                    6          4           4            4
# pizza                    2          2           5            3
#
#                 chocolate_cake  steak  pizza
# pork_chop                    5     46      7
# lasagna                      0      6     20
# french_toast                 6     10      7
# guacamole                    1      1      3
# apple_pie                    5      6      4
# cheesecake                  13      6      5
# hamburger                    2     12      2
# fried_rice                   2      3      9
# carrot_cake                 15      4      6
# chocolate_cake             134      6      2
# steak                       11     92      2
# pizza                        5      4    153

# %% [markdown]
# ##### Alexnet Layer 7 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_7_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_7_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.631  0.629      0.628   0.631

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.52    0.49      0.50    212.0
# lasagna              0.55    0.61      0.58    184.0
# french_toast         0.60    0.55      0.57    202.0
# guacamole            0.80    0.88      0.84    195.0
# apple_pie            0.53    0.47      0.50    207.0
# cheesecake           0.57    0.59      0.58    196.0
# hamburger            0.75    0.74      0.74    203.0
# fried_rice           0.75    0.76      0.76    202.0
# carrot_cake          0.63    0.60      0.62    212.0
# chocolate_cake       0.63    0.67      0.65    191.0
# steak                0.48    0.46      0.47    193.0
# pizza                0.73    0.77      0.75    203.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop             103       11            15          5          6
# lasagna                 9      112             6          1         11
# french_toast            8       14           111          3         18
# guacamole               0        2             1        171          1
# apple_pie              11       11            17          5         98
# cheesecake              2        5             4          1         14
# hamburger              11        4             6          2          8
# fried_rice              8        8             4          5          3
# carrot_cake             6        4             8          3         13
# chocolate_cake          2        2             5          3          5
# steak                  38       12             6         12          3
# pizza                   1       18             2          2          6
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                2          4           8            5
# lasagna                  2          6           7            5
# french_toast            13          5           5            3
# guacamole                0          8           6            2
# apple_pie               19          5           6           19
# cheesecake             116          4           4           14
# hamburger                3        150           1            1
# fried_rice               1          2         154            6
# carrot_cake             21          2           5          127
# chocolate_cake          17          2           0           16
# steak                    7         10           4            2
# pizza                    4          3           4            1
#
#                 chocolate_cake  steak  pizza
# pork_chop                    8     43      2
# lasagna                      1      4     20
# french_toast                 7     11      4
# guacamole                    1      2      1
# apple_pie                    8      4      4
# cheesecake                  19      8      5
# hamburger                    5     10      2
# fried_rice                   0      2      9
# carrot_cake                 14      2      7
# chocolate_cake             128      9      2
# steak                       10     88      1
# pizza                        3      2    157

# %% [markdown]
# ##### Alexnet Layer 6 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_6_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_alexnet/svm_alexnet_layer_6_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.591  0.591      0.592   0.591

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.45    0.46      0.45    212.0
# lasagna              0.53    0.66      0.59    184.0
# french_toast         0.52    0.49      0.51    202.0
# guacamole            0.81    0.85      0.83    195.0
# apple_pie            0.46    0.44      0.45    207.0
# cheesecake           0.55    0.55      0.55    196.0
# hamburger            0.66    0.65      0.65    203.0
# fried_rice           0.72    0.71      0.71    202.0
# carrot_cake          0.57    0.55      0.56    212.0
# chocolate_cake       0.64    0.64      0.64    191.0
# steak                0.45    0.43      0.44    193.0
# pizza                0.76    0.69      0.72    203.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              98       18            18          3         12
# lasagna                 7      121             7          4          5
# french_toast           16       14            99          2         25
# guacamole               3        3             0        166          2
# apple_pie               9       13            18          4         92
# cheesecake              4        1            10          0         13
# hamburger              12        7             9          7          9
# fried_rice             10       11             1          7         10
# carrot_cake             7        8            10          3         18
# chocolate_cake          6        2             5          3          2
# steak                  42       10             6          6          6
# pizza                   5       20             6          1          7
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                3         10           6            3
# lasagna                  3          3           8            8
# french_toast             8          9           1            8
# guacamole                6          6           4            0
# apple_pie               10          9           7           22
# cheesecake             107          9           6           15
# hamburger                5        131           3            2
# fried_rice               1          3         144            4
# carrot_cake             24          4           6          116
# chocolate_cake          17          4           2           16
# steak                    6          9           5            6
# pizza                    4          2           9            3
#
#                 chocolate_cake  steak  pizza
# pork_chop                    0     37      4
# lasagna                      0      6     12
# french_toast                 9     10      1
# guacamole                    2      3      0
# apple_pie                    9      7      7
# cheesecake                  21      6      4
# hamburger                    5     10      3
# fried_rice                   1      0     10
# carrot_cake                  7      8      1
# chocolate_cake             122     10      2
# steak                       14     83      0
# pizza                        2      4    140

# %% [markdown]
# ##### VGGNet Layer 8 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_8_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_8_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.685  0.683      0.682   0.685

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.55    0.54      0.54    211.0
# lasagna              0.65    0.65      0.65    187.0
# french_toast         0.70    0.62      0.66    208.0
# guacamole            0.87    0.89      0.88    189.0
# apple_pie            0.56    0.53      0.55    194.0
# cheesecake           0.68    0.70      0.69    206.0
# hamburger            0.67    0.74      0.70    200.0
# fried_rice           0.81    0.89      0.85    213.0
# carrot_cake          0.68    0.62      0.65    205.0
# chocolate_cake       0.66    0.76      0.71    178.0
# steak                0.57    0.50      0.53    211.0
# pizza                0.78    0.80      0.79    198.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop             113       18             7          1          6
# lasagna                11      122             3          0          8
# french_toast           11        6           130          4         14
# guacamole               0        1             0        169          1
# apple_pie               7        8            14          2        103
# cheesecake              5        2             7          1          8
# hamburger               6        3             3          7         12
# fried_rice              1        3             0          3          4
# carrot_cake             4        5             8          1         14
# chocolate_cake          2        2             0          1          3
# steak                  42        4            11          2          5
# pizza                   2       14             2          3          5
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                3          6          11            1
# lasagna                  1          6           6            4
# french_toast            15          8           1            6
# guacamole                0          7           6            2
# apple_pie               11         13           5           12
# cheesecake             144          5           1           11
# hamburger                4        148           0            5
# fried_rice               0          2         189            3
# carrot_cake             12          6           8          127
# chocolate_cake          18          2           0           11
# steak                    4         13           2            5
# pizza                    0          4           5            1
#
#                 chocolate_cake  steak  pizza
# pork_chop                    1     42      2
# lasagna                      2      6     18
# french_toast                 5      3      5
# guacamole                    1      0      2
# apple_pie                   10      6      3
# cheesecake                  17      1      4
# hamburger                    3      7      2
# fried_rice                   0      3      5
# carrot_cake                 14      6      0
# chocolate_cake             136      3      0
# steak                       15    105      3
# pizza                        2      1    159

# %% [markdown]
# ##### VGGNet Layer 7 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_7_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_7_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.685  0.684      0.684   0.685

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.55    0.51      0.53    211.0
# lasagna              0.67    0.61      0.64    187.0
# french_toast         0.64    0.62      0.63    208.0
# guacamole            0.90    0.89      0.90    189.0
# apple_pie            0.55    0.60      0.57    194.0
# cheesecake           0.70    0.67      0.68    206.0
# hamburger            0.71    0.76      0.73    200.0
# fried_rice           0.81    0.88      0.84    213.0
# carrot_cake          0.66    0.65      0.66    205.0
# chocolate_cake       0.70    0.76      0.73    178.0
# steak                0.54    0.51      0.52    211.0
# pizza                0.82    0.78      0.80    198.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop             108       16            11          0          5
# lasagna                10      114            10          1         12
# french_toast            9        3           129          4         18
# guacamole               0        0             0        169          4
# apple_pie               5        6            12          2        117
# cheesecake              3        3             8          0         15
# hamburger               4        3             9          3         10
# fried_rice              5        2             2          2          4
# carrot_cake             3        5             5          2         16
# chocolate_cake          0        2             2          1          5
# steak                  46        3            12          2          3
# pizza                   2       14             2          2          5
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                1          4           8            4
# lasagna                  3          5           5            4
# french_toast            14          7           1            5
# guacamole                0          6           5            1
# apple_pie               11         11           3           11
# cheesecake             137          2           2           14
# hamburger                4        151           0            4
# fried_rice               0          2         188            4
# carrot_cake             11          4           9          134
# chocolate_cake          11          3           0           16
# steak                    3         13           4            6
# pizza                    1          5           8            1
#
#                 chocolate_cake  steak  pizza
# pork_chop                    3     49      2
# lasagna                      1      9     13
# french_toast                 6      7      5
# guacamole                    2      1      1
# apple_pie                    5      7      4
# cheesecake                  17      3      2
# hamburger                    4      7      1
# fried_rice                   0      2      2
# carrot_cake                 12      4      0
# chocolate_cake             135      3      0
# steak                        7    108      4
# pizza                        2      1    155

# %% [markdown]
# ##### VGGNet Layer 6 Extracted Features

# %%
predictions = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_6_2016_08_17/predicted_labels")
actuals = np.load("../transfer-learning/models/svm_vggnet/svm_vggnet_layer_6_2016_08_17/test_labels")
predictions = np.array([x.decode() for x in predictions])
actuals = np.array([x.decode() for x in actuals])
score, metrics, confusion = hc.get_metrics(actuals, predictions, class_list)

# %%
score
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.641  0.642      0.643   0.641

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.50    0.52      0.51    211.0
# lasagna              0.60    0.58      0.59    187.0
# french_toast         0.62    0.62      0.62    208.0
# guacamole            0.86    0.86      0.86    189.0
# apple_pie            0.50    0.57      0.53    194.0
# cheesecake           0.63    0.61      0.62    206.0
# hamburger            0.72    0.68      0.70    200.0
# fried_rice           0.77    0.80      0.79    213.0
# carrot_cake          0.57    0.57      0.57    205.0
# chocolate_cake       0.65    0.69      0.67    178.0
# steak                0.52    0.48      0.50    211.0
# pizza                0.78    0.74      0.76    198.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop             110       11            14          0          6
# lasagna                15      108             6          2         10
# french_toast            8        3           129          2         23
# guacamole               4        1             0        162          3
# apple_pie               4        8            12          2        110
# cheesecake              6        6            10          0         16
# hamburger               7        4             8         10         13
# fried_rice              5        7             2          3          3
# carrot_cake             5       10            12          1         13
# chocolate_cake          3        3             1          3          7
# steak                  47        7            12          4          5
# pizza                   4       12             3          0         10
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                2          9           9            3
# lasagna                  3          3           6            8
# french_toast            10          7           1            7
# guacamole                2          3           7            3
# apple_pie               14          8           5           15
# cheesecake             125          4           1           16
# hamburger                4        136           1            7
# fried_rice               2          2         171            6
# carrot_cake             15          3           5          117
# chocolate_cake          16          2           0           13
# steak                    3          9           5            5
# pizza                    2          2          10            5
#
#                 chocolate_cake  steak  pizza
# pork_chop                    3     43      1
# lasagna                      1      8     17
# french_toast                 6      7      5
# guacamole                    0      3      1
# apple_pie                    5      7      4
# cheesecake                  19      1      2
# hamburger                    1      8      1
# fried_rice                   2      4      6
# carrot_cake                 17      5      2
# chocolate_cake             123      6      1
# steak                       12    101      1
# pizza                        1      2    147
