# %%
# %matplotlib inline
import skimage.io as io
import sklearn.cluster as cluster
from sklearn.decomposition import PCA
import glob, os
import numpy as np
import pandas as pd
import skimage.transform as transform
from skimage.color import rgb2gray
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.grid_search import GridSearchCV
from imp import reload
import sys
sys.path.append('../')
import helpers.histogram_classifier as hc

# %%
from IPython.core.display import HTML
css = open('styles/table-style.css').read() #+ open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
#     font-size: 12px;
# }
# table.dataframe tr {
#     border: none;
#     line-height: 14px;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.7em;
#     padding-right: 0.7em;
# }
# table.dataframe th {
#     background-color: #1c9099;
#     text-align: center;
#     font-weight: normal;
#     color: white;
# }
# table.dataframe td {
#     border: 1px solid #ccf;
#     background-color: #f4f4ff;
#     text-align: center;
# }
# </style>

# %%
classes = pd.read_csv('../data/food-101/meta/top_classes.csv', index_col=0)
class_list = list(classes['class'].unique())

image_names = {}
for c in class_list:
    image_names[c] = np.array(classes[classes['class'] == c]['name'])

# %%
def get_kmeans_features(class_list, image_names, size, color_type, num_features):
    """
    Get features using PCA for a dictionary of image names
    :params class_list: list of n image classes
    :params image_names: dictionary of m image names for each class
    :params size: standard size to use for images during PCA as tuple
    :params color_type: indicator of RGB or Greyscale
    :params num_features: number of features to extract
    :return: features: array of features of shape (n x m, num_features)
    :return: true_labels: array of true labels of length n x m
    """
    images = []
    true_labels = []
    
    for c in class_list:
        for i in image_names[c]:
            true_labels.append(c)
            img = io.imread(os.path.join('../data/food-101/top_classes/', c, '', i))
            img = transform.resize(img, size)
            if color_type == 'Greyscale':
                img = rgb2gray(img)
            images.append(img.reshape(-1, 1))
    alg = cluster.KMeans(n_clusters=num_features)
    y = np.array(images)
    features = alg.fit_transform(y.reshape(len(y), -1))
    
    return features, np.array(true_labels)

# %%
def get_pca_features(class_list, image_names, size, color_type, num_features):
    """
    Get features using PCA for a dictionary of image names
    :params class_list: list of n image classes
    :params image_names: dictionary of m image names for each class
    :params size: standard size to use for images during PCA as tuple
    :params color_type: indicator of RGB or Greyscale
    :params num_features: number of features to extract
    :return: features: array of features of shape (n x m, num_features)
    :return: true_labels: array of true labels of length n x m
    """
    images = []
    true_labels = []
    
    for c in class_list:
        for i in image_names[c]:
            true_labels.append(c)
            img = io.imread(os.path.join('../data/food-101/top_classes/', c, '', i))
            img = transform.resize(img, size)
            if color_type == 'Greyscale':
                img = rgb2gray(img)
            images.append(img.reshape(-1, 1))
    alg = PCA(n_components=num_features)
    y = np.array(images)
    features = alg.fit_transform(y.reshape(len(y), -1))
    
    return features, np.array(true_labels)

# %%
def get_pixel_features(class_list, image_names, size):
    """
    Get features using PCA for a dictionary of image names
    :params class_list: list of n image classes
    :params image_names: dictionary of m image names for each class
    :params size: standard size to use for images as tuple
    :return: features: array of features of shape (n x m, num_features)
    :return: true_labels: array of true labels of length n x m
    """
    features = []
    true_labels = []
    
    
    for c in class_list:
        for i in image_names[c]:
            img = io.imread(os.path.join('../data/food-101/top_classes/', c, '', i))
            img = transform.resize(img, size)
            features.append(img.reshape(-1))
            true_labels.append(c)
    
    return np.array(features), np.array(true_labels)

# %% [markdown]
# ### K-Means Features

# %%
train, test = hc.split_data(image_names, 0.75)

# %%
features, labels = get_kmeans_features(class_list, train, (32, 32, 3), 'RGB', 100)

# %%
test_features, test_labels = get_kmeans_features(class_list, test, (30, 30, 3), 'RGB', 100)

# %% [markdown]
# ##### k-Nearest Neighbors

# %%
knn = KNeighborsClassifier()

# %%
# %%time
knn.fit(features, labels)
# Out:
# CPU times: user 35.9 ms, sys: 1.83 ms, total: 37.8 ms
# Wall time: 36.3 ms
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# %%time
predictions = knn.predict(test_features)
# Out:
# CPU times: user 7.72 s, sys: 55.4 ms, total: 7.77 s
# Wall time: 7.86 s

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.091  0.084      0.091   0.091

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.02    0.00      0.01    250.0
# lasagna              0.08    0.11      0.09    250.0
# french_toast         0.09    0.20      0.12    250.0
# guacamole            0.08    0.03      0.04    250.0
# apple_pie            0.12    0.09      0.10    250.0
# cheesecake           0.09    0.03      0.05    250.0
# hamburger            0.07    0.10      0.08    250.0
# fried_rice           0.13    0.06      0.08    250.0
# carrot_cake          0.11    0.18      0.14    250.0
# chocolate_cake       0.17    0.14      0.15    250.0
# steak                0.09    0.04      0.06    250.0
# pizza                0.06    0.10      0.08    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop               1       26            49         11         11
# lasagna                 7       27            46         10         18
# french_toast            1       32            51          8         16
# guacamole               9       43            47          8         14
# apple_pie               4       33            45          6         22
# cheesecake              6       20            58          8         14
# hamburger               4       36            48         10         11
# fried_rice              8       35            33          7         31
# carrot_cake             5       23            47          7         15
# chocolate_cake          1       21            52          8         11
# steak                   2       25            54          9          8
# pizza                  11       34            42         14         13
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                8         36          10           33
# lasagna                  8         34          13           28
# french_toast             8         41           7           29
# guacamole                5         32          11           37
# apple_pie                6         25          16           37
# cheesecake               8         30          13           35
# hamburger                9         26          13           34
# fried_rice               2         36          16           31
# carrot_cake             10         24           9           45
# chocolate_cake           9         37           4           25
# steak                   10         26           3           39
# pizza                    8         37          12           39
#
#                 chocolate_cake  steak  pizza
# pork_chop                   23      5     37
# lasagna                      9      5     45
# french_toast                18      8     31
# guacamole                    7     14     23
# apple_pie                   18      7     31
# cheesecake                  17     14     27
# hamburger                   11      7     41
# fried_rice                   7      6     38
# carrot_cake                 22      8     35
# chocolate_cake              35     19     28
# steak                       32     10     32
# pizza                        9      6     25

# %% [markdown]
# #### Random Forest Classifier

# %%
rf = RandomForestClassifier(max_depth=5, n_estimators=15)

# %%
# %%time
rf.fit(features, labels)
# Out:
# CPU times: user 523 ms, sys: 4.88 ms, total: 528 ms
# Wall time: 527 ms
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=15, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# %%time
predictions = rf.predict(test_features)
# Out:
# CPU times: user 10.8 ms, sys: 32 ms, total: 42.8 ms
# Wall time: 41.9 ms

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.108  0.093      0.106   0.108

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.11    0.08      0.09    250.0
# lasagna              0.07    0.14      0.10    250.0
# french_toast         0.17    0.01      0.02    250.0
# guacamole            0.07    0.03      0.04    250.0
# apple_pie            0.12    0.14      0.13    250.0
# cheesecake           0.13    0.11      0.12    250.0
# hamburger            0.10    0.04      0.06    250.0
# fried_rice           0.11    0.16      0.13    250.0
# carrot_cake          0.04    0.01      0.01    250.0
# chocolate_cake       0.16    0.31      0.21    250.0
# steak                0.11    0.06      0.08    250.0
# pizza                0.09    0.20      0.12    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              20       33             2         16         11
# lasagna                23       36             1          6         25
# french_toast           10       34             2          9         24
# guacamole               9       57             0          8         27
# apple_pie              19       39             1          9         35
# cheesecake             16       32             0          9         20
# hamburger              15       45             0          8         24
# fried_rice             24       28             3         11         36
# carrot_cake            11       39             1          9         28
# chocolate_cake         19       39             1         10         18
# steak                  11       56             1         21         16
# pizza                  10       44             0          6         25
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                8         10          27            4
# lasagna                 11          3          39            6
# french_toast            13          9          30            3
# guacamole               31         18          25            4
# apple_pie               25          3          32            4
# cheesecake              27          7          16            6
# hamburger               12         10          31            4
# fried_rice              15          5          40            4
# carrot_cake             18         12          26            2
# chocolate_cake          12          5          17            7
# steak                   15          7          19            5
# pizza                   26         10          52            2
#
#                 chocolate_cake  steak  pizza
# pork_chop                   58     15     46
# lasagna                     25      9     66
# french_toast                44      6     66
# guacamole                   15     14     42
# apple_pie                   34      8     41
# cheesecake                  63     14     40
# hamburger                   27     15     59
# fried_rice                  19      6     59
# carrot_cake                 55     11     38
# chocolate_cake              78     18     26
# steak                       48     15     36
# pizza                       14     10     51

# %% [markdown]
# ### PCA Features

# %%
train, test = hc.split_data(image_names, 0.75)

# %%
features, labels = get_pca_features(class_list, train, (30, 30, 3), 'RGB', 100)

# %%
test_features, test_labels = get_pca_features(class_list, test, (30, 30, 3), 'RGB', 100)

# %% [markdown]
# ##### k-Nearest Neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
# %%time
knn.fit(features, labels)
# Out:
# CPU times: user 43.9 ms, sys: 1.85 ms, total: 45.8 ms
# Wall time: 44.7 ms
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=9, p=2,
#            weights='uniform')

# %%
# %%time
predictions = knn.predict(test_features)
# Out:
# CPU times: user 5.78 s, sys: 18.6 ms, total: 5.8 s
# Wall time: 5.82 s

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.063  0.051      0.059   0.063

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.05    0.02      0.03    250.0
# lasagna              0.08    0.06      0.07    250.0
# french_toast         0.05    0.02      0.02    250.0
# guacamole            0.04    0.03      0.03    250.0
# apple_pie            0.08    0.22      0.12    250.0
# cheesecake           0.04    0.04      0.04    250.0
# hamburger            0.11    0.04      0.06    250.0
# fried_rice           0.06    0.20      0.10    250.0
# carrot_cake          0.09    0.07      0.08    250.0
# chocolate_cake       0.01    0.00      0.01    250.0
# steak                0.06    0.01      0.02    250.0
# pizza                0.03    0.04      0.03    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop               5       13             4         23         60
# lasagna                 6       16             7         14         63
# french_toast            6       16             4         18         56
# guacamole              11       16             5          7         51
# apple_pie              13       14             6         10         56
# cheesecake             10       20             9         20         42
# hamburger               6       16             7         14         54
# fried_rice              9       22             7          7         59
# carrot_cake            18       18             8         17         52
# chocolate_cake          7       19             8         26         64
# steak                   4       22             6         23         57
# pizza                   8       12             6          9         51
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop               27          4          60           19
# lasagna                 29         12          52           19
# french_toast            26         10          60           18
# guacamole               14         13          90           14
# apple_pie               22          7          58           12
# cheesecake              10          7          76           13
# hamburger               23         11          67           15
# fried_rice              27          8          50           10
# carrot_cake             16         10          51           17
# chocolate_cake          14          7          65           13
# steak                   22          6          64           15
# pizza                   26          8          91           16
#
#                 chocolate_cake  steak  pizza
# pork_chop                    5      1     29
# lasagna                      6      3     23
# french_toast                 6      1     29
# guacamole                    4      6     19
# apple_pie                   18      7     27
# cheesecake                   8      8     27
# hamburger                    2      3     32
# fried_rice                  13      7     31
# carrot_cake                  8      7     28
# chocolate_cake               1      1     25
# steak                        1      3     27
# pizza                       11      3      9

# %% [markdown]
# ##### Random Forest

# %%
rf = RandomForestClassifier()

# %%
# %%time
rf.fit(features, labels)
# Out:
# CPU times: user 983 ms, sys: 25 ms, total: 1.01 s
# Wall time: 1.01 s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# %%time
predictions = rf.predict(test_features)
# Out:
# CPU times: user 13.9 ms, sys: 1.34 ms, total: 15.3 ms
# Wall time: 13.7 ms

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.071  0.067      0.069   0.071

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.06    0.03      0.04    250.0
# lasagna              0.07    0.06      0.06    250.0
# french_toast         0.09    0.09      0.09    250.0
# guacamole            0.07    0.06      0.06    250.0
# apple_pie            0.09    0.18      0.12    250.0
# cheesecake           0.06    0.08      0.07    250.0
# hamburger            0.09    0.06      0.08    250.0
# fried_rice           0.08    0.08      0.08    250.0
# carrot_cake          0.08    0.12      0.09    250.0
# chocolate_cake       0.04    0.04      0.04    250.0
# steak                0.06    0.03      0.04    250.0
# pizza                0.05    0.03      0.04    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop               7       23            17         15         39
# lasagna                13       15            20         19         36
# french_toast           13       22            22         16         47
# guacamole              12       14            31         15         30
# apple_pie              14       14             8         21         44
# cheesecake             15       26            26         22         38
# hamburger               7       16            17         20         23
# fried_rice              9       19            21         12         39
# carrot_cake             8       17            28         18         40
# chocolate_cake          9       13            22         16         49
# steak                   5       21            22         24         46
# pizza                  15       15            14         27         38
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop               21         20          26           35
# lasagna                 28         10          25           34
# french_toast            18         20          21           27
# guacamole               30          6          25           27
# apple_pie               29         16          15           35
# cheesecake              20         15          23           27
# hamburger               33         16          22           47
# fried_rice              33         17          20           29
# carrot_cake             22         22          13           29
# chocolate_cake          32         13          27           31
# steak                   31         10          20           27
# pizza                   24         11          26           36
#
#                 chocolate_cake  steak  pizza
# pork_chop                   24      7     16
# lasagna                     22     18     10
# french_toast                22      6     16
# guacamole                   36     12     12
# apple_pie                   27     13     14
# cheesecake                  20      9      9
# hamburger                   16     16     17
# fried_rice                  21     14     16
# carrot_cake                 26     14     13
# chocolate_cake              10     13     15
# steak                       23      8     13
# pizza                       26     10      8

# %% [markdown]
# ### Pixels as Features

# %%
train, test = hc.split_data(image_names, 0.75)

# %%
features, labels = get_pixel_features(class_list, train, (32, 32, 3))

# %%
test_features, test_labels = get_pixel_features(class_list, test, (32, 32, 3))

# %% [markdown]
# ##### k-Nearest Neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
# %%time
knn.fit(features, labels)
# Out:
# CPU times: user 2.19 s, sys: 27.7 ms, total: 2.22 s
# Wall time: 2.23 s
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=9, p=2,
#            weights='uniform')

# %%
# %%time
predictions = knn.predict(test_features)
# Out:
# CPU times: user 2min 25s, sys: 850 ms, total: 2min 26s
# Wall time: 2min 27s

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.143  0.133      0.203   0.143

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.32    0.13      0.19    250.0
# lasagna              0.15    0.13      0.14    250.0
# french_toast         0.14    0.04      0.06    250.0
# guacamole            0.25    0.11      0.15    250.0
# apple_pie            0.10    0.39      0.16    250.0
# cheesecake           0.13    0.28      0.18    250.0
# hamburger            0.13    0.03      0.05    250.0
# fried_rice           0.12    0.27      0.16    250.0
# carrot_cake          0.13    0.09      0.11    250.0
# chocolate_cake       0.35    0.09      0.14    250.0
# steak                0.29    0.05      0.08    250.0
# pizza                0.34    0.12      0.17    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              33       28             9          6         68
# lasagna                 5       32             8          6         85
# french_toast            2       18            10          3         78
# guacamole               2       13             5         27         85
# apple_pie               2       10             4         11         97
# cheesecake              9       10             2          7         66
# hamburger               6       17             7          7         80
# fried_rice              3       15             5          9         83
# carrot_cake             8       13             3         10         87
# chocolate_cake         18       15             5          5         73
# steak                  14       29             6          6         66
# pizza                   2       16             7         10         87
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop               28          3          40           15
# lasagna                 33          7          51            8
# french_toast            40          4          69           16
# guacamole               45          5          53            3
# apple_pie               49          5          55            9
# cheesecake              70          5          44           27
# hamburger               52          8          53           13
# fried_rice              54          1          67            8
# carrot_cake             57          6          32           23
# chocolate_cake          41          4          27           27
# steak                   33         13          35           21
# pizza                   39          1          52            5
#
#                 chocolate_cake  steak  pizza
# pork_chop                    7      6      7
# lasagna                      5      2      8
# french_toast                 1      2      7
# guacamole                    2      4      6
# apple_pie                    1      0      7
# cheesecake                   5      2      3
# hamburger                    1      2      4
# fried_rice                   1      1      3
# carrot_cake                  4      1      6
# chocolate_cake              22      9      4
# steak                       13     12      2
# pizza                        1      1     29

# %% [markdown]
# ##### Random Forest

# %%
rf = RandomForestClassifier(n_estimators=14, max_depth=7)

# %%
# %%time
rf.fit(features, labels)
# Out:
# CPU times: user 3.09 s, sys: 56.4 ms, total: 3.14 s
# Wall time: 3.15 s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=14, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# %%time
predictions = rf.predict(test_features)
# Out:
# CPU times: user 33.1 ms, sys: 28.3 ms, total: 61.4 ms
# Wall time: 60.1 ms

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.207  0.192      0.191   0.207

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.18    0.20      0.19    250.0
# lasagna              0.20    0.20      0.20    250.0
# french_toast         0.13    0.07      0.09    250.0
# guacamole            0.27    0.30      0.29    250.0
# apple_pie            0.11    0.06      0.08    250.0
# cheesecake           0.21    0.22      0.21    250.0
# hamburger            0.11    0.04      0.06    250.0
# fried_rice           0.23    0.33      0.27    250.0
# carrot_cake          0.19    0.13      0.16    250.0
# chocolate_cake       0.24    0.43      0.31    250.0
# steak                0.17    0.18      0.18    250.0
# pizza                0.24    0.31      0.27    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              50       21            13          6          4
# lasagna                16       51            17         20         15
# french_toast           28       33            18         14         15
# guacamole              18       10             7         76         12
# apple_pie               9       30             9         20         15
# cheesecake             19       17             8         12         15
# hamburger              23       23            15         27          8
# fried_rice             16       17             9         36         16
# carrot_cake            19       14            10         16         19
# chocolate_cake         25        4             5         11          6
# steak                  40       13            14         16          2
# pizza                  16       21            13         23         11
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop               12          9          10            8
# lasagna                 13          8          46           12
# french_toast            21          9          29           16
# guacamole               11          9          37           10
# apple_pie               28         12          47           15
# cheesecake              54          7          24           19
# hamburger               18         10          27           11
# fried_rice              19          9          83            6
# carrot_cake             31          9          16           33
# chocolate_cake          21          4           4           20
# steak                   12          4           4           10
# pizza                   18          5          36           10
#
#                 chocolate_cake  steak  pizza
# pork_chop                   56     45     16
# lasagna                     10     15     27
# french_toast                25     13     29
# guacamole                   21     21     18
# apple_pie                   20     11     34
# cheesecake                  42     13     20
# hamburger                   31     27     30
# fried_rice                   4      9     26
# carrot_cake                 43     22     18
# chocolate_cake             108     36      6
# steak                       74     46     15
# pizza                        7     13     77

# %% [markdown]
# ### Chained Features - RGB Histogram + Pixels

# %%
train, test = hc.split_data(image_names, 0.75)

# %%
def get_chained_features(image_class, image_name, size):
    img = io.imread(os.path.join('../data/food-101/top_classes/', image_class, '', image_name))
    #Histogram features
    features = hc.color_histogram(img)
    #Pixel features
    img = transform.resize(img, size)
    features = np.append(features, img.reshape(-1))
    
    return features

# %%
def create_features(class_list, image_names, size):
    labels = []
    features = []
    for c in class_list:
        for i in image_names[c]:
            labels.append(c)
            features.append(get_chained_features(c, i, size))
    return np.array(features), np.array(labels)

# %%
features, labels = create_features(class_list, train, (32, 32, 3))

# %%
test_features, test_labels = create_features(class_list, test, (32, 32, 3))

# %% [markdown]
# ##### KNN

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
# %%time
knn.fit(features, labels)
# Out:
# CPU times: user 2.42 s, sys: 34.7 ms, total: 2.46 s
# Wall time: 2.48 s
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=9, p=2,
#            weights='uniform')

# %%
# %%time
predictions = knn.predict(test_features)
# Out:
# CPU times: user 2min 28s, sys: 1.2 s, total: 2min 29s
# Wall time: 2min 32s

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy     F1  Precision  Recall
# Results     0.175  0.171      0.178   0.175

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.18    0.14      0.16    250.0
# lasagna              0.12    0.07      0.09    250.0
# french_toast         0.13    0.24      0.17    250.0
# guacamole            0.26    0.25      0.25    250.0
# apple_pie            0.13    0.13      0.13    250.0
# cheesecake           0.22    0.12      0.16    250.0
# hamburger            0.13    0.17      0.14    250.0
# fried_rice           0.20    0.31      0.24    250.0
# carrot_cake          0.13    0.11      0.12    250.0
# chocolate_cake       0.26    0.20      0.22    250.0
# steak                0.16    0.10      0.12    250.0
# pizza                0.23    0.26      0.24    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              36        9            43         12         20
# lasagna                13       17            51         13         21
# french_toast            9       20            60         12         21
# guacamole              17       10            23         62         14
# apple_pie              18       14            43         11         33
# cheesecake             15        9            25         17         34
# hamburger              13       10            36         20         12
# fried_rice              7       12            35         19         21
# carrot_cake            13       16            48         12         29
# chocolate_cake         23        4            27         22         20
# steak                  27       11            37         17         18
# pizza                   5       12            27         20         18
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop                6         32          13           18
# lasagna                 11         25          32           11
# french_toast             8         38          27            8
# guacamole                9         33          32           12
# apple_pie               14         27          49           13
# cheesecake              31         16          24           25
# hamburger                6         42          47           19
# fried_rice               7         28          78           11
# carrot_cake             15         20          30           27
# chocolate_cake          24         18           7           24
# steak                    5         23          10           33
# pizza                    7         31          38           13
#
#                 chocolate_cake  steak  pizza
# pork_chop                   18     23     20
# lasagna                      6     11     39
# french_toast                 9      6     32
# guacamole                   12      9     17
# apple_pie                    5      6     17
# cheesecake                  22     17     15
# hamburger                    5     11     29
# fried_rice                   8      5     19
# carrot_cake                 20     10     10
# chocolate_cake              49     23      9
# steak                       28     24     17
# pizza                        5      8     66

# %% [markdown]
# ##### Random Forest

# %%
rf = RandomForestClassifier(n_estimators=70, max_depth=10)

# %%
# %%time
rf.fit(features, labels)
# Out:
# CPU times: user 25.1 s, sys: 208 ms, total: 25.3 s
# Wall time: 26.6 s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=70, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# %%time
predictions = rf.predict(test_features)
# Out:
# CPU times: user 136 ms, sys: 24.8 ms, total: 161 ms
# Wall time: 165 ms

# %%
overall, metrics, confusion = hc.get_metrics(test_labels, predictions, class_list)

# %%
overall
# Out:
#          Accuracy    F1  Precision  Recall
# Results      0.27  0.26      0.262    0.27

# %%
metrics
# Out:
#                 Precision  Recall  F1-Score  Support
# pork_chop            0.23    0.21      0.22    250.0
# lasagna              0.25    0.20      0.22    250.0
# french_toast         0.27    0.17      0.21    250.0
# guacamole            0.29    0.40      0.34    250.0
# apple_pie            0.22    0.10      0.13    250.0
# cheesecake           0.30    0.34      0.32    250.0
# hamburger            0.22    0.23      0.22    250.0
# fried_rice           0.28    0.37      0.32    250.0
# carrot_cake          0.18    0.12      0.14    250.0
# chocolate_cake       0.40    0.46      0.42    250.0
# steak                0.21    0.26      0.23    250.0
# pizza                0.30    0.39      0.34    250.0

# %%
confusion
# Out:
#                 pork_chop  lasagna  french_toast  guacamole  apple_pie  \
# pork_chop              52       18            15          9          3
# lasagna                13       51            19         23          8
# french_toast           20       23            42         12          9
# guacamole               6        4             4        101          9
# apple_pie              11       28            14         22         24
# cheesecake             10       10             8         23          6
# hamburger              21       14            16         42          4
# fried_rice              6        6             8         39         13
# carrot_cake            16       19            13         17         20
# chocolate_cake         21        3             4         11          0
# steak                  50        6             8         19          3
# pizza                   3       25             6         26         12
#
#                 cheesecake  hamburger  fried_rice  carrot_cake  \
# pork_chop               12         17          10           10
# lasagna                 18         19          27           13
# french_toast            10         24          23           19
# guacamole               10         25          33            8
# apple_pie               23         18          49           18
# cheesecake              86         11          23           17
# hamburger               12         57          22            8
# fried_rice              20         24          92            2
# carrot_cake             40         12          19           29
# chocolate_cake          31         13           1           12
# steak                   12         23           2           14
# pizza                   13         20          23            9
#
#                 chocolate_cake  steak  pizza
# pork_chop                   30     59     15
# lasagna                      7     13     39
# french_toast                 8     25     35
# guacamole                   11     25     14
# apple_pie                    6     12     25
# cheesecake                  32     11     13
# hamburger                    9     15     30
# fried_rice                   2     12     26
# carrot_cake                 23     26     16
# chocolate_cake             114     35      5
# steak                       43     64      6
# pizza                        2     13     98

# %% [markdown]
# ##### Grid Search for Params for Random Forest

# %%
depth = np.array([8, 10, 12])
estimators = np.array([50, 60, 70])

# %%
model = RandomForestClassifier()

# %%
grid = GridSearchCV(estimator=model, param_grid=dict(n_estimators=estimators, max_depth=depth))

# %%
grid.fit(features, labels)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_depth': array([ 8, 10, 12]), 'n_estimators': array([50, 60, 70])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
print(grid.best_score_)
# Out:
# 0.273

# %%
print(grid.best_estimator_.n_estimators)
# Out:
# 70

# %%
print(grid.best_estimator_.max_depth)
# Out:
# 10
